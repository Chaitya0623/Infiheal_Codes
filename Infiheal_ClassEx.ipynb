# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitya0623/Infiheal_Codes/blob/main/Infiheal_ClassEx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

df = pd.read_excel('/content/CANCER MUTATIONS_Shubham.xlsx')
df

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 63.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 74.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.2 MB/s eta 0:00:00
# ...

# %%
# %timeit
from transformers import pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli", device=0)

# %%
import gc

# You can then use this pipeline to classify sequences into any of the class names you specify.

for i in range(len(df)):
  gc.collect()
  sequence_to_classify=df['Example'][i]
  candidate_labels =  [ 'Kras Mutation',
  'P-Ten Mutation',
  'P-53 Mutation',
  'MLH1',
  'MSH2',
  'MSH6'
  ]
  output = classifier(sequence_to_classify, candidate_labels, multi_label=False)
  for key, value in output.items():
    if key == 'labels':
      df['Type'][i] = value[0]
  if i%20==0:
    print(i)

# %%
df
# Out:
#               Type                                            Example
# 0    Kras Mutation  When I was diagnosed with colorectal cancer, m...
# 1    Kras Mutation  As someone with a KRAS mutation, I know that I...
# 2    Kras Mutation  When my father was diagnosed with pancreatic c...
# 3    Kras Mutation  Finding out that my lung cancer had a KRAS mut...
# 4    Kras Mutation  Living with a KRAS mutation can be scary, but ...
# ..             ...                                                ...
# 548           MSH6  Living with MSH6: My Journey with Lynch Syndro...
# 549           MSH6  Navigating MSH6: My Story of Lynch Syndrome I ...
# 550           MSH6  Finding Strength in MSH6: Overcoming Challenge...
# 551           MSH6  Embracing Life with MSH6: A Journey of Lynch S...
# 552           MSH6  Living Beyond MSH6: Thriving with Lynch Syndro...
#
# [553 rows x 2 columns]

# %%
df.to_excel('CANCER MUTATIONS_Chait_Sid.xlsx')

# %%
data = pd.read_excel("CANCER MUTATIONS_Chait_Sid.xlsx").drop(columns=["Unnamed: 0"])

# %%
data.to_excel('CANCER MUTATIONS_Chait_Sid.xlsx')
