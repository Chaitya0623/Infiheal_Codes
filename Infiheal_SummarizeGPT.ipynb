# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitya0623/Infiheal_Codes/blob/main/Infiheal_SummarizeGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

df = pd.read_excel('/content/CANCER MUTATIONS_Shubham.xlsx')
df

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 63.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 24.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 76.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.5 MB/s eta 0:00:00
# ...

# %%
# %timeit
from transformers import pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli", device=0)
# Out:
# Your max_length is set to 1000, but your input_length is only 313. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=156)
# [{'summary_text': "Me (23M) and my boyfriend (26M) are having this specific problem regarding our love languages. He gets his need for quality time, but I don't get my need for physical touch. The only time we can hug or at least hold hands is when we go in inns or hotels."}]

# %%
import gc

# You can then use this pipeline to classify sequences into any of the class names you specify.

for i in range(len(df)):
  gc.collect()
  sequence_to_classify=df['Example'][i]
  candidate_labels = [
    "Angry",
    "Empathetic",
    "Calm",
    "Excited",
    "Sarcastic",
    "Playful",
    "Formal",
    "Informal",
    "Authoritative",
    "Persuasive",
    "Optimistic",
    "Pessimistic",
    "Confident",
    "Nostalgic",
    "Melancholic",
    "Sincere",
    "Suspenseful",
    "Humorous",
    "Sympathetic",
    "Reflective",
    "Critical",
    "Satirical",
    "Objective",
    "Frustrated",
    "Loving",
    "Hopeful",
    "Bittersweet",
    "Inquisitive",
    "Urgent",
    "Dramatic",
    "Energetic",
    "Contemplative",
    "Thoughtful",
    "Cynical",
    "Casual",
    "Matter-of-fact",
    "Resolute",
    "Dismissive",
    "Apologetic",
    "Indifferent",
    "Inspirational",
    "Scornful",
    "Descriptive",
    "Whimsical",
    "Soothing",
    "Disappointed",
    "Surprised",
    "Serious",
    "Joyful",
    "Bewildered"
  ]
  output = classifier(sequence_to_classify, candidate_labels, multi_label=False)
  for key, value in output.items():
    if key == 'labels':
      df['Type'][i] = value[0]
  if i%20==0:
    print(i)
# Out:
# 687

# %%
len(ARTICLE)
# Out:
# 1292

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
model = AutoModelForCausalLM.from_pretrained("akoksal/LongForm-OPT-1.3B")
tokenizer = AutoTokenizer.from_pretrained("akoksal/LongForm-OPT-1.3B")

instruction = "Write an essay about meditation. [EOI]"
torch.manual_seed(42)
input_ids = tokenizer(instruction, return_tensors="pt").input_ids
target_ids = model.generate(input_ids, do_sample=True, max_new_tokens=50, top_p=0.9)
tokenizer.decode(target_ids[0])
# Output:
# > Write an essay about meditation. [EOI]Meditation, or yoga, is a mind/body
# method that is practiced to improve focus, reduce stress and anxiety,
# increase concentration, promote positive emotion, and enhance wellbeing.
# Meditation is an art, a meditation technique that we can take time
# Out:
# ...
# '</s>Write an essay about meditation. [EOI]Meditation is a powerful and useful tool for both physical and mental health.  Although the practice of meditation can be very relaxing, there are many different types of meditation.  There are also many different types of meditation exercises.  This essay is going'

# %%
# %pip install "accelerate>=0.16.0,<1" "transformers[torch]>=4.28.1,<5" "torch>=1.13.1,<2"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 101.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 26.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 69.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 79.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import torch
from transformers import pipeline

generate_text = pipeline(model="databricks/dolly-v2-3b", torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto", device=0)
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/databricks/dolly-v2-3b:
# - instruct_pipeline.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# Both `device` and `device_map` are specified. `device` will override `device_map`. You will most likely encounter unexpected behavior. Please remove `device` and keep `device_map`.
# ...
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# ...

# %%
res = generate_text('''Summarize the following text while keeping the tone of a therapist: It's normal for people to feel disinterested or uncomfortable with certain characteristics or inclinations in a potential partner. You may not relate to the idea of gifts being a significant aspect of a relationship, and that's perfectly acceptable! you might think giving gifts might be a bit materialistic or shallow in a relationship, but usually, people who consider it a love language say that the thought behind it matters the most. then again, we have no way of knowing if that was what was intended by him. Every person has their own principles and priorities, and what suits one may not suit another. that's why it's important to be truthful with oneself about one's desires in a partner and to locate someone whose values and priorities match one's own, and I am glad that you sorted this out within yourself! although it might be helpful to remember that love languages are a tool to communicate effectively and understand one another. it's a bridge to better displaying each other's feelings. when partners use this, they express the love that makes sense to their partner the most and make them feel loved. even though we sometimes might not like doing this or that, the "greatest" love language is compromise and understanding. You can find a compromise by exploring other love languages that you both enjoy, such as words of affirmation, quality time, or acts of service. what i am trying to say is, it is rarely a selection criteria for choosing partners, rather than just a way to show love and appreciation. would you like to explore more on love languages and other topics that might strengthen your relationships? YES/NO''',temperature=0.7, top_p=1.0,)
print(res[0]["generated_text"])
# Out:
# Hi there,
# It is good to hear that you are comfortable with the idea of gifts being a significant aspect of a relationship. It is important to be honest with oneself about one's feelings and desires in a partner and to communicate effectively and understand one another. This is an important skill to learn in a relationship.
#
# I hope you find someone whose values and priorities match your own.

# %%
# !pip install langchain openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 3.8 MB/s eta 0:00:00
# ...

# %%
from langchain.llms import OpenAI

llm = OpenAI(openai_api_key="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")

# %%
from langchain import PromptTemplate

template = """
question: {question}

Extract the tone of of the question.

Tone:
"""

question='''it was all good like 3 months back, as time goes by im starting to see we are just really different people and we keep getting into petty fights about everything. i'm afraid this is not gonna work out.. idk'''
text='''I am so sorry you are going through something like that! That sounds really difficult to deal with... you must know that you don't deserve to be treated like this in a relationship. Without any information on both of your backgrounds, it is hard to tell where this is coming from, so I will have to make some assumptions here.. but firstly, I want to let you know that these behaviors indeed indicate that your boyfriend is being physically abusive. you mention he does behave properly sometimes, but there might be some hidden signs even in the "normal" behaviors that you might be ignoring. if your partner is being physically abusive, he also might be doing these too-

1. unreasonable things set him off. you walk on eggshells around him, you don't know what will make him angry and he might hit you again.
2. when he wants affection or sex, you have to comply, but the same isn't true for you. He also might nag you about sex even if you don't want to do it.
3. when you disagree, he might get really agitated and angry and wants you to do things by him
4. he tries to control your decisions about how you live your life- this can be done with words that look like he is looking out for you ( "you would look so much better in that dress", your friends don't seem like good people")
5. tries to isolate you from anyone whom he doesn't like
6. tries to control your finances or tells you to give up your job ("I will take care of you, don't worry")
overall, how a partner behaves when they are in a "bad mood", is not a reasonable metric for how healthy a relationship is at all. In a relationship, your partner should have the basic respect to act reasonably even when they are going through tough times, as the same goes for you. Couples should support each other - and it sounds like your situation is far away from real support. if a partner hits you at any point in time, my advice would be to leave such a relationship as you might be in mortal danger. I understand leaving can be difficult if you are financially dependent, in that case, we have helplines available.

People become abusive because of many reasons such as childhood trauma, unprocessed emotions, issues with trust and commitment, etc. But, thinking about how the partner became abusive, only adds to the confusion and indecisiveness of the victim about whether to leave the relationship or not. We have to remember that one partner cannot be a rehabilitation center for another partner! the onus of changing such toxic behavior should be on your partner, not you. Trauma can explain bad behavior but it does not excuse it. We may not be responsible for what happened to us in our childhood, but we are responsible for healing it. which in this case, is your partner. that being said, we then also have to talk about how you can heal. that brings me to my next point.

It can also prove beneficial to look a bit deep within ourselves, especially if you feel that it's difficult to leave emotionally. Abusers often play out their own dysfunctions and this isn't really in our control (most of the time at least) ... and because they lack self-awareness unlike you, they are likely to never change. You might also know deep down that if you stay, you won't get the treatment you deserve. After all, People can only meet you how they meet themselves. What we do have in control though, is our own reactions to these abusive situations. Even when we start eventually notice that some behaviors of our partners are not justifiable, why we do not confront and try to justify it at times? Why do we put up behaviors that we don't deserve? Why do we feel like we might be "able to fix this", as if it's our responsibility to do so? Asking these hard questions can lead us to the path where we find answers to our healing, which might lie in our own upbringing. The need to feel love and be loved at any cost, fear that we will have to be alone, or our partner will leave us if we don't love them "enough", or thinking we don't even deserve love can all play into this. My guess is that you may have some harmful passive behaviors are instilled within you- trying to please people to avoid conflict, problems with being assertive with your wants and needs and the inability to put up strong boundaries. you would be surprised to know how common these actually are, unfortunately. if you think something like this might be happening with you, would you like to explore that with me? YES/NO, TAKE ME TO THE HELPLINES
'''
prompt = PromptTemplate.from_template(template)
formatted_prompt = prompt.format(question=question)

# %%
formatted_prompt
# Out:
# '\ntext: I am so sorry you are going through something like that! That sounds really difficult to deal with... you must know that you don\'t deserve to be treated like this in a relationship. Without any information on both of your backgrounds, it is hard to tell where this is coming from, so I will have to make some assumptions here.. but firstly, I want to let you know that these behaviors indeed indicate that your boyfriend is being physically abusive. you mention he does behave properly sometimes, but there might be some hidden signs even in the "normal" behaviors that you might be ignoring. if your partner is being physically abusive, he also might be doing these too-\n\n1. unreasonable things set him off. you walk on eggshells around him, you don\'t know what will make him angry and he might hit you again.\n2. when he wants affection or sex, you have to comply, but the same isn\'t true for you. He also might nag you about sex even if you don\'t want to do it. \n3. when you disa
# ...

# %%
from langchain.chains import LLMChain

chain = LLMChain(llm=llm, prompt=prompt)
chain.run(formatted_prompt)
# Out:
# 'The tone of the question is one of worry and concern.'
